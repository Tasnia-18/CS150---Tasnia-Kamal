# %% [markdown]
# # Tasnia Kamal-Makdown practice

# %% [markdown]
# ### I am tasnia ,I love learning new things ,that is the reason behind chosing Data sciecne as my 2nd major

# %% [markdown]
# Course Activities
# - Programming Assignments
# - Quizzes
# - Attendance
# - Mid-Term Exam
# - Project

# %% [markdown]
# Ordered list
# 1. Moodle 1
# 2. Moodle 2
# 3. Moodle 3
# 4. Moodle 4
# 5. Moodle 5
# 6. Moodle 6
# 7. Moodle 7
# 8. Moodle 8
# 9. Moodle 9
# 10. Moodle 10

# %% [markdown]
# The primary Language is **Python**

# %% [markdown]
# I am using *Jupyter Notebook* to create and edit the .ipynb file.

# %% [markdown]
# Today I learned about `str`.

# %% [markdown]
# [My GitHub Account](https://github.com/Tasnia-18/CS150---Tasnia-Kamal)

# %% [markdown]
# ![University Logo](Uni_logo.png)

# %% [markdown]
# Today I learned how to create bullet lists, numbered lists, bold and italic text, backticks, hyperlinks, and display images in Markdown.
